# %%
import pandas as pd

# %% [markdown]
# # import data

# %%
area_spm = pd.read_csv('C:/Users/l_v_v/Documents/GitHub/py6s_harmonize_sample/datasets/Parameters Time series/area_SPM_time_series.csv').drop(columns=['Unnamed: 0'])
precipitation = pd.read_csv('C:/Users/l_v_v/Documents/GitHub/py6s_harmonize_sample/datasets/Parameters Time series/mean_precip_acum.csv')
discharge = pd.read_csv('C:/Users/l_v_v/Documents/GitHub/py6s_harmonize_sample/datasets/Parameters Time series/mean_watershed_discharge.csv')
wind = pd.read_csv('C:/Users/l_v_v/Documents/GitHub/py6s_harmonize_sample/datasets/Parameters Time series/mean_watershed_wind.csv')

# %% [markdown]
# # organize dataframes

# %%
print('colunms area', area_spm.columns)
print('colunms precipitation', precipitation.columns)
print('colunms discharge', discharge.columns)
print('colunms wind', wind.columns)
# Out:
# colunms area Index(['area_km2', 'mean_SPM', 'max_SPM', 'min_SPM', 'stdDev_SPM', 'month_end',
#        'month_init', 'timestamp', 'year', 'WATER_PERIOD'],
#       dtype='object')
# colunms precipitation Index(['mean_precipitation', 'month', 'timestamp', 'year'], dtype='object')
# colunms discharge Index(['water_period', 'year', 'start_month', 'Maxima', 'Minima', 'Media'], dtype='object')
# colunms wind Index(['mean_u__wind', 'mean_v__wind', 'month', 'timestamp', 'year'], dtype='object')

# %%
area_spm = area_spm[['area_km2', 'mean_SPM', 'max_SPM', 'min_SPM', 'stdDev_SPM', 
       'month_init', 'year', 'WATER_PERIOD']].copy()
precipitation = precipitation[['mean_precipitation', 'month', 'year']].copy()
discharge = discharge[['water_period', 'year', 'start_month', 'Maxima', 'Minima', 'Media']].copy()
wind = wind[['mean_u__wind', 'mean_v__wind', 'month', 'year']].copy()

# %%
area_spm.columns = ['area_km2', 'mean_SPM', 'max_SPM', 'min_SPM', 'stdDev_SPM', 
       'month_init', 'year', 'water_period']
precipitation.columns = ['mean_precipitation', 'month_init', 'year']
discharge.columns = ['water_period', 'year', 'month_init', 'discharge_max', 'discharge_min', 'discharge_mean']
wind.columns = ['mean_u__wind', 'mean_v__wind', 'month_init', 'year']

# %%
def add_period(row):
    if row['month_init'] == 1 or row['month_init']== 2 or row['month_init'] == 3:
        val = 'R'
    elif row['month_init'] == 4 or row['month_init'] == 5 or row['month_init'] == 6:
        val = 'HW'
    elif row['month_init'] == 7 or row['month_init'] == 8 or row['month_init'] == 9:
        val = 'F'
    else:
        val = 'LW'
    return val

precipitation['water_period'] = precipitation.apply(add_period, axis=1)
wind['water_period'] = wind.apply(add_period, axis=1)

# %% [markdown]
# # merge dataframes

# %%
df_pt1 =  pd.merge(area_spm, precipitation, how="inner", on=["month_init", "year",'water_period'])
df_pt1
# Out:
#        area_km2    mean_SPM     max_SPM   min_SPM  stdDev_SPM  month_init  \
# 0    989.084758   73.535345  306.049042  6.644032   51.890127           1
# 1   1335.446135   22.679618  282.490112  5.844900   15.929416           7
# 2    983.227657  134.038118  306.049042  8.780909   74.673074          10
# 3   1134.171724   93.210925  306.049042  6.623919   65.276331           1
# 4   1335.085554   18.724521  282.490112  5.401382   15.715166           4
# ..          ...         ...         ...       ...         ...         ...
# 83   463.786451  208.968305  306.049042  6.781344   61.418259          10
# 84   949.024621   36.722792  306.049042  5.868872   20.214386           1
# 85  1296.697903   32.580176  282.490112  5.754973   18.713887           4
# 86  1268.924408   39.458892  226.239838  5.868872   12.820446           7
# 87   390.826379  198.915826  306.049042  6.048137   66.096093          10
#
#     year water_period  mean_precipitation
# 0   2000            R         1290.486720
# 1   2000            F          249.195781
# 2   2000           LW          207.142783
# 3   2001            R         1104.292270
# 4   2001           HW          684.242645
# ..   ...          ...                 ...
# 83  2023           LW          173.824400
# 84  2024            R          875.257258
# 85  2024           HW          924.966354
# 86  2024            F           72.889736
# 87  2024           LW          306.114477
#
# [88 rows x 9 columns]

# %%
df_pt2 =  pd.merge(discharge, wind, how="inner", on=["month_init", "year",'water_period'])
df_pt2
# Out:
#    water_period  year  month_init  discharge_max  discharge_min  \
# 0             R  2000           1  180970.060000  152791.390000
# 1            HW  2000           4  227387.056667  213442.970000
# 2             F  2000           7  210227.493333  187716.696667
# 3            LW  2000          10  131677.151667  112206.038667
# 4             R  2001           1  180008.923333  151748.301667
# ..          ...   ...         ...            ...            ...
# 93            F  2023           7  193004.146667  150315.096667
# 94           LW  2023          10   86783.280000   63105.949667
# 95            R  2024           1  150532.343333  127500.926667
# 96           HW  2024           4  199498.360000  171633.060000
# 97           LW  2024          10   61237.440000   50618.246000
#
#     discharge_mean  mean_u__wind  mean_v__wind
# 0    167251.600000     -0.933975     -0.411431
# 1    221137.763333     -1.415435     -0.156260
# 2    199513.620000     -1.645349      0.055660
# 3    119414.215000     -1.344241      0.158495
# 4    165210.756667     -1.400858     -0.424053
# ..             ...           ...           ...
# 93   174020.018667     -2.135300     -0.319460
# 94    71733.411333     -2.151992     -0.081562
# 95   140132.016667     -1.783048     -0.281890
# 96   185468.000000     -1.509690     -0.353761
# 97    54955.098000     -1.758324     -0.094365
#
# [98 rows x 8 columns]

# %%
df_total = pd.merge(df_pt1, df_pt2, how="inner", on=["month_init", "year",'water_period'])
df_total
# Out:
#        area_km2    mean_SPM     max_SPM   min_SPM  stdDev_SPM  month_init  \
# 0    989.084758   73.535345  306.049042  6.644032   51.890127           1
# 1   1335.446135   22.679618  282.490112  5.844900   15.929416           7
# 2    983.227657  134.038118  306.049042  8.780909   74.673074          10
# 3   1134.171724   93.210925  306.049042  6.623919   65.276331           1
# 4   1335.085554   18.724521  282.490112  5.401382   15.715166           4
# ..          ...         ...         ...       ...         ...         ...
# 81  1393.733107   27.691303  233.446442  5.801264   10.494394           7
# 82   463.786451  208.968305  306.049042  6.781344   61.418259          10
# 83   949.024621   36.722792  306.049042  5.868872   20.214386           1
# 84  1296.697903   32.580176  282.490112  5.754973   18.713887           4
# 85   390.826379  198.915826  306.049042  6.048137   66.096093          10
#
#     year water_period  mean_precipitation  discharge_max  discharge_min  \
# 0   2000            R         1290.486720  180970.060000  152791.390000
# 1   2000            F          249.195781  210227.493333  187716.696667
# 2   2000           LW          207.142783  131677.151667  112206.038667
# 3   2001            R         1104.292270  180008.923333  151748.301667
# 4   2001           HW          684.242645  225499.916667  217867.040000
# ..   ...          ...                 ...            ...            ...
# 81  2023            F           80.883509  193004.146667  150315.096667
# 82  2023           LW          173.824400   86783.280000   63105.949667
# 83  2024            R          875.257258  150532.343333  127500.926667
# 84  2024           HW          924.966354  199498.360000  171633.060000
# 85  2024           LW          306.114477   61237.440000   50618.246000
#
#     discharge_mean  mean_u__wind  mean_v__wind
# 0    167251.600000     -0.933975     -0.411431
# 1    199513.620000     -1.645349      0.055660
# 2    119414.215000     -1.344241      0.158495
# 3    165210.756667     -1.400858     -0.424053
# 4    222300.540000     -1.321960     -0.093279
# ..             ...           ...           ...
# 81   174020.018667     -2.135300     -0.319460
# 82    71733.411333     -2.151992     -0.081562
# 83   140132.016667     -1.783048     -0.281890
# 84   185468.000000     -1.509690     -0.353761
# 85    54955.098000     -1.758324     -0.094365
#
# [86 rows x 14 columns]

# %%
df_total.to_csv('C:/Users/l_v_v/Documents/GitHub/py6s_harmonize_sample/datasets/Parameters Time series/merged_df/df_merged.csv')
