# %% [markdown]
# <a href="https://colab.research.google.com/github/larissavaladao/py6s_harmonize_sample/blob/main/manage_data%20/data_analysis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # importar pacotes

# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importar dados

# %%
df_ld8 = pd.read_csv('/content/drive/MyDrive/CURUAI_PROCESS/merge_LD8prio_data.csv').drop(['Unnamed: 0'],axis=1)

# %%
df_ld8.head()
# Out:
#    CHLOROPHYLL  CHLOROPHYLL_A       CHLOROPHYLL_B  CLOUD_COVER  DEPTH_CLASS  \
# 0     0.699333        2.14404  1.9471400000000005         51.0            1
# 1     0.827333       10.23478   8.205020000000001         51.0            1
# 2     1.210000       44.09388            19.88334         51.0            1
# 3     0.478824        5.24614   4.278520000000001         51.0            1
# 4     0.633000        4.23382              < 0,01         51.0            1
#
#      DOC  ID  LATITUDE LOCATION  LONGITUDE  ...   nir_min  nir_stdDev  \
# 0  2.854   3 -2.196960       LG -55.299530  ...  0.014668    0.000803
# 1  1.017   4 -2.221738       LG -55.270194  ...  0.011887    0.000818
# 2  1.390   8 -2.209570       LG -55.347110  ...  0.008830    0.000882
# 3  3.665  16 -2.262023       PQ -55.456187  ...  0.019592    0.000661
# 4  3.980  21 -2.133265       GP -55.488798  ...  0.012886    0.000758
#
#     red_max  red_mean red_median   red_min  red_stdDev  \
# ...

# %%
df_minDate = pd.read_csv('/content/drive/MyDrive/CURUAI_PROCESS/merge_min_data.csv').drop(['Unnamed: 0'],axis=1)

# %%
df_minDate['CHLOROPHYLL_B'].head()
# Out:
# 0    1.9471400000000005
# 1     8.205020000000001
# 2              19.88334
# 3     4.278520000000001
# 4                < 0,01
# Name: CHLOROPHYLL_B, dtype: object

# %% [markdown]
# ## visualizar dados SPM

# %%
sns.relplot(data=df_minDate, x="blue_mean", y="SPM", hue="WATER_PERIOD", style='satellite')
sns.relplot(data=df_minDate, x="green_mean", y="SPM", hue="WATER_PERIOD", style='satellite')
sns.relplot(data=df_minDate, x="red_mean", y="SPM", hue="WATER_PERIOD", style='satellite')
sns.relplot(data=df_minDate, x="nir_mean", y="SPM", hue="WATER_PERIOD", style='satellite')

# %%
sns.relplot(data=df_ld8, x="blue_mean", y="SPM", hue="WATER_PERIOD", style='satellite')
sns.relplot(data=df_ld8, x="green_mean", y="SPM", hue="WATER_PERIOD", style='satellite')
sns.relplot(data=df_ld8, x="red_mean", y="SPM", hue="WATER_PERIOD", style='satellite')
sns.relplot(data=df_ld8, x="nir_mean", y="SPM", hue="WATER_PERIOD", style='satellite')

# %%
df_ld8_clean = df_ld8.loc[df_ld8['ID'] != 232].copy()
df_minDate_clean = df_minDate.loc[df_minDate['ID'] != 232].copy()

# %%
df_ld8_clean.columns
# Out:
# Index(['CHLOROPHYLL', 'CHLOROPHYLL_A', 'CHLOROPHYLL_B', 'CLOUD_COVER',
#        'DEPTH_CLASS', 'DOC', 'ID', 'LATITUDE', 'LOCATION', 'LONGITUDE',
#        'MISSION', 'N_TOTAL', 'N_TOTAL_DISSOLVED', 'POC', 'P_ORGANIC',
#        'P_TOTAL', 'SAMPLE_SITE', 'SAMPLING_DEPTH', 'SILICA', 'SPM', 'TOC',
#        'TOTAL_DEPTH', 'TURBIDITY', 'WATER_PERIOD', 'blue_max', 'blue_mean',
#        'blue_median', 'blue_min', 'blue_stdDev', 'count_pixel', 'datetime',
#        'dif_date_point', 'green_max', 'green_mean', 'green_median',
#        'green_min', 'green_stdDev', 'img_date', 'nir_max', 'nir_mean',
#        'nir_median', 'nir_min', 'nir_stdDev', 'red_max', 'red_mean',
#        'red_median', 'red_min', 'red_stdDev', 'system_index',
#        'dif_date_point_abs', 'satellite'],
#       dtype='object')

# %%
sns.relplot(data=df_minDate_clean, x="blue_mean", y="SPM", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="green_mean", y="SPM", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="red_mean", y="SPM", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="nir_mean", y="SPM", hue="WATER_PERIOD", style='MISSION')

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="SPM",order=1)
sns.lmplot(data=df_minDate_clean, x="green_mean", y="SPM",order=1)
sns.lmplot(data=df_minDate_clean, x="red_mean", y="SPM",order=1)
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="SPM",order=2 )

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="SPM",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="green_mean", y="SPM",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="red_mean", y="SPM",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="SPM",order=1, col="WATER_PERIOD")#, style='MISSION')

# %%
sns.relplot(data=df_minDate_clean, x="blue_mean", y="CHLOROPHYLL_A", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="green_mean", y="CHLOROPHYLL_A", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="red_mean", y="CHLOROPHYLL_A", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="nir_mean", y="CHLOROPHYLL_A", hue="WATER_PERIOD", style='MISSION')

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="CHLOROPHYLL_A",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="green_mean", y="CHLOROPHYLL_A",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="red_mean", y="CHLOROPHYLL_A",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="CHLOROPHYLL_A",order=1, col="WATER_PERIOD")#, style='MISSION')

# %%
sns.relplot(data=df_minDate_clean, x="blue_mean", y="DOC", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="green_mean", y="DOC", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="red_mean", y="DOC", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="nir_mean", y="DOC", hue="WATER_PERIOD", style='MISSION')

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="DOC",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="green_mean", y="DOC",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="red_mean", y="DOC",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="DOC",order=1, col="WATER_PERIOD")#, style='MISSION')

# %%
sns.relplot(data=df_minDate_clean, x="blue_mean", y="N_TOTAL_DISSOLVED", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="green_mean", y="N_TOTAL_DISSOLVED", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="red_mean", y="N_TOTAL_DISSOLVED", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="nir_mean", y="N_TOTAL_DISSOLVED", hue="WATER_PERIOD", style='MISSION')

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="N_TOTAL_DISSOLVED",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="green_mean", y="N_TOTAL_DISSOLVED",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="red_mean", y="N_TOTAL_DISSOLVED",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="N_TOTAL_DISSOLVED",order=1, col="WATER_PERIOD")#, style='MISSION')

# %%
sns.relplot(data=df_minDate_clean, x="blue_mean", y="P_TOTAL", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="green_mean", y="P_TOTAL", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="red_mean", y="P_TOTAL", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="nir_mean", y="P_TOTAL", hue="WATER_PERIOD", style='MISSION')

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="P_TOTAL",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="green_mean", y="P_TOTAL",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="red_mean", y="P_TOTAL",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="P_TOTAL",order=1, col="WATER_PERIOD")#, style='MISSION')

# %%
sns.relplot(data=df_minDate_clean, x="blue_mean", y="SILICA", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="green_mean", y="SILICA", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="red_mean", y="SILICA", hue="WATER_PERIOD", style='MISSION')
sns.relplot(data=df_minDate_clean, x="nir_mean", y="SILICA", hue="WATER_PERIOD", style='MISSION')

# %%
sns.lmplot(data=df_minDate_clean, x="blue_mean", y="SILICA",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="green_mean", y="SILICA",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="red_mean", y="SILICA",order=1, col="WATER_PERIOD")#, style='MISSION')
sns.lmplot(data=df_minDate_clean, x="nir_mean", y="SILICA",order=1, col="WATER_PERIOD")#, style='MISSION')
