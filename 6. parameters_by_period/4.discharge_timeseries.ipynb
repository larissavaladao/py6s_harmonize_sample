# %% [markdown]
# # import and install packages

# %%
import pandas as pd
import seaborn as sns

# %%
# import discharge database

df = pd.read_csv('C:/Users/l_v_v/Documents/GitHub/py6s_harmonize_sample/datasets/HydroWeb/17050001_Vazoes.csv')
df.columns
# Out:
# Index(['EstacaoCodigo', 'NivelConsistencia', 'Data', 'Hora', 'MediaDiaria',
#        'MetodoObtencaoVazoes', 'Maxima', 'Minima', 'Media', 'DiaMaxima',
#        'DiaMinima', 'MaximaStatus', 'MinimaStatus', 'MediaStatus',
#        'MediaAnual', 'MediaAnualStatus', 'Vazao01', 'Vazao02', 'Vazao03',
#        'Vazao04', 'Vazao05', 'Vazao06', 'Vazao07', 'Vazao08', 'Vazao09',
#        'Vazao10', 'Vazao11', 'Vazao12', 'Vazao13', 'Vazao14', 'Vazao15',
#        'Vazao16', 'Vazao17', 'Vazao18', 'Vazao19', 'Vazao20', 'Vazao21',
#        'Vazao22', 'Vazao23', 'Vazao24', 'Vazao25', 'Vazao26', 'Vazao27',
#        'Vazao28', 'Vazao29', 'Vazao30', 'Vazao31', 'Vazao01Status',
#        'Vazao02Status', 'Vazao03Status', 'Vazao04Status', 'Vazao05Status',
#        'Vazao06Status', 'Vazao07Status', 'Vazao08Status', 'Vazao09Status',
#        'Vazao10Status', 'Vazao11Status', 'Vazao12Status', 'Vazao13Status',
#        'Vazao14Status', 'Vazao15Status', 'Vazao16Status', 'Vazao17Status',
#        'Vazao18Status', 'Vazao19Status', 'Vazao20Status', 'Vazao21Status',
#        'Vazao22Status', 'Vazao23Status', 'Vazao24Status', 'Vazao25Status',
#        'Vazao26Status', 'Vazao27Status', 'Vazao28Status', 'Vazao29Status',
#        'Vazao30Status', 'Vazao31Status'],
#       dtype='object')

# %%
def add_period(row):
    if row['Data'][3:5] == '01' or row['Data'][3:5] == '02' or row['Data'][3:5] == '03':
        val = 'R'
    elif row['Data'][3:5] == '04' or row['Data'][3:5] == '05' or row['Data'][3:5] == '06':
        val = 'HW'
    elif row['Data'][3:5] == '07' or row['Data'][3:5] == '08' or row['Data'][3:5] == '09':
        val = 'F'
    else:
        val = 'LW'
    return val

def add_start_period(row):
    if row['Data'][3:5] == '01' or row['Data'][3:5] == '02' or row['Data'][3:5] == '03':
        val = 1
    elif row['Data'][3:5] == '04' or row['Data'][3:5] == '05' or row['Data'][3:5] == '06':
        val = 4
    elif row['Data'][3:5] == '07' or row['Data'][3:5] == '08' or row['Data'][3:5] == '09':
        val = 7
    else:
        val = 10
    return val

def add_start_year(row):
    return int(row['Data'][6:10])

# %%
df['water_period'] = df.apply(add_period, axis=1)
df['start_month'] = df.apply(add_start_period, axis=1)
df['year'] = df.apply(add_start_year, axis=1)
df
# Out:
#      EstacaoCodigo  NivelConsistencia        Data  Hora  MediaDiaria  \
# 0         17050001                  1  01/10/2024   NaN            1
# 1         17050001                  1  01/04/2024   NaN            1
# 2         17050001                  1  01/03/2024   NaN            1
# 3         17050001                  1  01/02/2024   NaN            1
# 4         17050001                  1  01/01/2024   NaN            1
# ..             ...                ...         ...   ...          ...
# 669       17050001                  2  01/05/1968   NaN            1
# 670       17050001                  2  01/04/1968   NaN            1
# 671       17050001                  2  01/03/1968   NaN            1
# 672       17050001                  2  01/02/1968   NaN            1
# 673       17050001                  2  01/01/1968   NaN            1
#
#      MetodoObtencaoVazoes     Maxima      Minima       Media  DiaMaxima  ...  \
# 0                       1   61237.44   50618.246   54955.098        1.0  ...
# 1                       1  199498.36  171633.060  185468.000       30.0  ...
# 2                       1  171400.97  150210.660  161591.580       31.0  ...
# 3                       1  149589.05  131000.770  140958.220       29.0  ...
# 4                       1  130607.01  101291.350  117846.250       31.0  ...
# ..                    ...        ...         ...         ...        ...  ...
# 669                     1  203907.97  186702.720  197769.300       28.0  ...
# 670                     1  185510.23  164029.530  173898.780       30.0  ...
# 671                     1  164029.53  147318.080  154791.720       31.0  ...
# 672                     1        NaN         NaN         NaN        NaN  ...
# 673                     1  120000.00  103000.000  110677.420       31.0  ...
#
#      Vazao25Status  Vazao26Status  Vazao27Status  Vazao28Status  \
# 0              NaN            NaN            NaN            NaN
# 1              1.0            1.0            1.0            1.0
# 2              1.0            1.0            1.0            1.0
# 3              1.0            1.0            1.0            1.0
# 4              1.0            1.0            1.0            1.0
# ..             ...            ...            ...            ...
# 669            1.0            1.0            1.0            1.0
# 670            1.0            1.0            1.0            1.0
# 671            1.0            1.0            1.0            1.0
# 672            1.0            1.0            1.0            1.0
# 673            0.0            0.0            0.0            0.0
#
#      Vazao29Status  Vazao30Status  Vazao31Status  water_period  start_month  \
# 0              NaN            NaN            NaN            LW           10
# 1              1.0            1.0            0.0            HW            4
# 2              1.0            1.0            1.0             R            1
# 3              1.0            0.0            0.0             R            1
# 4              1.0            1.0            1.0             R            1
# ..             ...            ...            ...           ...          ...
# 669            1.0            1.0            1.0            HW            4
# 670            1.0            1.0            NaN            HW            4
# 671            1.0            1.0            1.0             R            1
# 672            1.0            NaN            NaN             R            1
# 673            0.0            0.0            0.0             R            1
#
#      year
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# ..    ...
# 669  1968
# 670  1968
# 671  1968
# 672  1968
# 673  1968
#
# [674 rows x 81 columns]

# %%
df_discharge = df[['EstacaoCodigo','Data',  'Maxima', 'Minima', 'Media','water_period',
'start_month','year']].copy()
df_discharge.describe()
# Out:
#        EstacaoCodigo         Maxima         Minima          Media  \
# count          674.0     661.000000     661.000000     673.000000
# mean      17050001.0  179260.637598  158070.055555  168624.140530
# std              0.0   45048.747056   48336.029515   46952.358378
# min       17050001.0   61237.440000   50618.246000   54955.098000
# 25%       17050001.0  144038.160000  114100.340000  127891.984000
# 50%       17050001.0  185272.050000  159477.530000  174545.230000
# 75%       17050001.0  217327.980000  200964.660000  209988.800000
# max       17050001.0  274744.220000  269368.660000  272205.200000
#
#        start_month         year
# count   674.000000   674.000000
# mean      5.464392  1995.597923
# std       3.356404    16.247713
# min       1.000000  1968.000000
# 25%       1.000000  1982.000000
# 50%       4.000000  1996.000000
# 75%       7.000000  2010.000000
# max      10.000000  2024.000000

# %%
df_discharge['Data']=pd.to_datetime(df_discharge['Data'],format="%d/%m/%Y")

# %%
df_discharge.dtypes
# Out:
# EstacaoCodigo             int64
# Data             datetime64[ns]
# Maxima                  float64
# Minima                  float64
# Media                   float64
# water_period             object
# start_month               int64
# year                      int64
# dtype: object

# %%
df_discharge.head()
# Out:
#    EstacaoCodigo       Data     Maxima      Minima       Media water_period  \
# 0       17050001 2024-10-01   61237.44   50618.246   54955.098           LW
# 1       17050001 2024-04-01  199498.36  171633.060  185468.000           HW
# 2       17050001 2024-03-01  171400.97  150210.660  161591.580            R
# 3       17050001 2024-02-01  149589.05  131000.770  140958.220            R
# 4       17050001 2024-01-01  130607.01  101291.350  117846.250            R
#
#    start_month  year
# 0           10  2024
# 1            4  2024
# 2            1  2024
# 3            1  2024
# 4            1  2024

# %%
df_discharge = df_discharge.loc[(df_discharge['Data'] > pd.to_datetime('2000-01-01')) & (df_discharge['Data'] < pd.to_datetime('2025-01-01'))]
df_discharge
# Out:
#      EstacaoCodigo       Data     Maxima      Minima       Media water_period  \
# 0         17050001 2024-10-01   61237.44   50618.246   54955.098           LW
# 1         17050001 2024-04-01  199498.36  171633.060  185468.000           HW
# 2         17050001 2024-03-01  171400.97  150210.660  161591.580            R
# 3         17050001 2024-02-01  149589.05  131000.770  140958.220            R
# 4         17050001 2024-01-01  130607.01  101291.350  117846.250            R
# ..             ...        ...        ...         ...         ...          ...
# 284       17050001 2000-06-01  231542.98  223636.860  227736.890           HW
# 285       17050001 2000-05-01  230773.88  220601.100  227064.900           HW
# 286       17050001 2000-04-01  219844.31  196090.950  208611.500           HW
# 287       17050001 2000-03-01  195848.31  165403.440  181084.640            R
# 288       17050001 2000-02-01  166091.81  140179.340  153418.560            R
#
#      start_month  year
# 0             10  2024
# 1              4  2024
# 2              1  2024
# 3              1  2024
# 4              1  2024
# ..           ...   ...
# 284            4  2000
# 285            4  2000
# 286            4  2000
# 287            1  2000
# 288            1  2000
#
# [289 rows x 8 columns]

# %%
aggregated_data = df_discharge.groupby(['water_period', 'year','start_month']).agg(
    Maxima=('Maxima', 'mean'),
    Minima=('Minima', 'mean'),
    Media=('Media', 'mean')
)

# %%
aggregated_data = aggregated_data.transform(lambda x: x.rank(ascending=False))
# Out:
#                                       Maxima         Minima          Media
# water_period year start_month
# F            2000 7            210227.493333  187716.696667  199513.620000
#              2001 7            196338.923333  165046.180000  181597.236667
#              2002 7            206412.983333  181938.063333  195080.746667
#              2003 7            198514.033333  175022.753333  187919.586667
#              2004 7            180898.533333  158592.700000  170339.840000
# ...                                      ...            ...            ...
# R            2020 1            186606.373333  168109.313333  177699.610000
#              2021 1            200623.566667  167182.446667  184382.646667
#              2022 1            211572.380000  185956.980000  198530.183333
#              2023 1            182737.576667  147524.150000  164682.760000
#              2024 1            150532.343333  127500.926667  140132.016667
#
# [98 rows x 3 columns]
